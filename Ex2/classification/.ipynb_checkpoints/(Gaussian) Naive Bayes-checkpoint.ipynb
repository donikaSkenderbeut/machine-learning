# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/wine-quality-preprocessed.csv')
df.head()
# Out:
#    volatile acidity  residual sugar  chlorides  total sulfur dioxide  density  \
# 0              0.70        0.641854  -2.577022              3.526361   0.9978
# 1              0.88        0.955511  -2.322788              4.204693   0.9968
# 2              0.76        0.832909  -2.385967              3.988984   0.9970
# 3              0.28        0.641854  -2.590267              4.094345   0.9980
# 4              0.70        0.641854  -2.577022              3.526361   0.9978
#
#      pH  sulphates   alcohol  quality
# 0  3.51       0.56  2.240710        0
# 1  3.20       0.68  2.282382        0
# 2  3.26       0.65  2.282382        0
# 3  3.16       0.58  2.282382        1
# 4  3.51       0.56  2.240710        0

# %%
df[(df['quality'] > 0)]
# Out:
#       volatile acidity  residual sugar  chlorides  total sulfur dioxide  \
# 3                 0.28        0.641854  -2.590267              4.094345
# 7                 0.65        0.182322  -2.733368              3.044522
# 8                 0.58        0.693147  -2.617296              2.890372
# 14                0.28        0.587787  -2.385967              4.634729
# 16                0.22        0.587787  -2.563950              4.094345
# ...                ...             ...        ...                   ...
# 1471              0.51        0.832909  -2.577022              3.688879
# 1472              0.62        0.641854  -2.688248              3.637586
# 1474              0.55        0.788457  -2.780621              3.931826
# 1475              0.51        0.832909  -2.577022              3.688879
# 1477              0.31        1.280934  -2.703063              3.737670
#
#       density    pH  sulphates   alcohol  quality
# 3     0.99800  3.16       0.58  2.282382        1
# ...

# %%
def prior_probability(df, label):
    p = df[label][(df[label] == 1)].count()
    n = df[label].count()
    return [p/n, 1-p/n]

def likelyhood_probability(df, feature,x, label):
    #only considering values with given outcome
    df = df[(df['quality'] == label)]
    mean = df[feature].mean()
    sd = df[feature].std()
    #build gaussian distribution PDF
    prob = (1 / (sd * np.sqrt(2 * np.pi))) * (np.exp(-(1/2) * ((x-mean)/sd)**2))
    return prob


def naive_bayes (df, X):
    features = list(X.columns)
    prior = prior_probability(df, 'quality')
    y_pred = []
    for x in X:
        print(x)
        likelyhood = [1,1]
        for l in range(2):
            for f in range(len(features)):
                print(x[f])
                likelyhood[l] *= likelyhood_probability(df, features[f],x[f],l)
        
        post = [0,0]
        for l in range(2):
            post[l] = likelyhood[l] * prior[l]
        
        y_pred.apped(np.argmax(post))
    return np.array(y_pred)

# %%
X = df.loc[:, df.columns != 'quality']
naive_bayes(df,X)
# Out:
# volatile acidity
# v
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In [33], line 2
#       1 X = df.loc[:, df.columns != 'quality']
# ----> 2 naive_bayes(df,X)
#
# Cell In [32], line 26, in naive_bayes(df, X)
#      24     for f in range(len(features)):
#      25         print(x[f])
# ---> 26         likelyhood[l] *= likelyhood_probability(df, features[f],x[f],l)
#      28 post = [0,0]
#      29 for l in range(2):
#
# Cell In [32], line 12, in likelyhood_probability(df, feature, x, label)
#      10 sd = df[feature].std()
#      11 #build gaussian distribution PDF
# ---> 12 prob = (1 / (sd * np.sqrt(2 * np.pi))) * (np.exp(-(1/2) * ((x-mean)/sd)**2))
#      13 return prob
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U1'), dtype('float64')) -> None
